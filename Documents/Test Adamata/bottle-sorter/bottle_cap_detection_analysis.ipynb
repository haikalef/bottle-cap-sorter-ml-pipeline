# %%
# !pip install --upgrade ultralytics pyyaml opencv-python numpy wandb
# Out:
# Requirement already satisfied: ultralytics in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (8.3.228)
# Requirement already satisfied: pyyaml in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (6.0.3)
# Requirement already satisfied: opencv-python in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (2.0.2)
# Requirement already satisfied: wandb in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (0.23.0)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (3.9.4)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (2.8.0)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (0.23.0)
# Requirement already satisfied: psutil in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: click>=8.0.1 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (8.1.8)
# Requirement already satisfied: eval-type-backport in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (0.3.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (3.1.45)
# Requirement already satisfied: packaging in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (4.3.7)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (6.33.1)
# Requirement already satisfied: pydantic<3 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (2.12.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (2.44.0)
# Requirement already satisfied: typing-extensions<5,>=4.8 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from wandb) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from pydantic<3->wandb) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from click>=8.0.1->wandb) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.21.0)
# Requirement already satisfied: six>=1.5 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: filelock in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: polars-runtime-32==1.35.2 in c:\users\haikalef\anaconda3\envs\ml_env\lib\site-packages (from polars->ultralytics) (1.35.2)

# %%
import wandb
#login wandb
wandb.login() 
print("WandB login berhasil! Siap untuk tracking eksperimen.")
# Out:
# wandb: Currently logged in as: haikalef8 (haikalef8-) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# WandB login berhasil! Siap untuk tracking eksperimen.

# %%
import os
import cv2
import numpy as np
import yaml
import sys
import torch
import random
import time
from pathlib import Path
from ultralytics import YOLO
import pandas as pd
from typing import List, Dict, Any, Tuple

# RANDOM SEED (Untuk Konsistensi Hasil)
SEED = 42 

def set_seed(seed):
    """Mengatur seed untuk semua sumber keacakan (torch, numpy, random)"""
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(SEED)
print(f"Random seed diatur ke {SEED}")

# DEFINISI PATH
data_root = Path('./data/raw_bottles/') 
target_root = Path('./data/bottles_relabelled/') 

# Path Output Model 
project_name_dir = './ada-mata-bottle-cap-sorting'
model_path_baseline = Path(f'{project_name_dir}/yolov8n_baseline_run/weights/best.pt') 
model_path_revisi = Path(f'{project_name_dir}/yolov8n_regularized_run/weights/best.pt') 

test_image_path = Path('./data/bottles_relabelled/images/test/raw-250110_dc_s001_b3_2.jpg')
# Out:
# Random seed diatur ke 42

# %%
# --- KONFIGURASI WARNA HSV (OpenCV: H: 0-179, S,V: 0-255) ---
blue_h_min = 90    # Batas Hue minimum untuk warna Biru
blue_h_max = 140   # Batas Hue maksimum untuk warna Biru
light_v_threshold = 160 # Ambang batas Value (Kecerahan) untuk membedakan Light/Dark

def get_yolo_class(img_hsv: np.ndarray) -> int:
    """
    Menentukan kelas warna tutup botol (0: Light Blue, 1: Dark Blue, 2: Others)
    berdasarkan nilai rata-rata HSV dari patch gambar.
    """
    if img_hsv.size == 0:
        # Menangani patch kosong jika bounding box terlalu kecil atau tidak valid
        return 2 # Default ke Others

    # Hitung rata-rata H, S, V di dalam bounding box
    h_mean, s_mean, v_mean, _ = cv2.mean(img_hsv)

    # 1. Cek apakah warna adalah BIRU (berdasarkan Hue)
    if blue_h_min <= h_mean <= blue_h_max:
        # Jika Hue dalam rentang Biru
        if v_mean > light_v_threshold:
            # Value tinggi -> Light Blue (Kelas 0)
            return 0  
        else:
            # Value rendah -> Dark Blue (Kelas 1)
            return 1  
    else:
        # Bukan Biru
        return 2  # Others (Kelas 2)

def relabel_dataset(source_path: Path, target_path: Path, train_ratio: float = 0.8, val_ratio: float = 0.1) -> None:
    """
    Memproses dan menyesuaikan label kelas YOLO dari dataset asli berdasarkan warna tutup botol.
    Hasilnya akan dibagi menjadi train, val, dan test set.
    """
    print("--- Memulai Penyesuaian Label Dataset ---")
    
    # Cek dan buat folder output
    (target_path / "images" / "train").mkdir(parents=True, exist_ok=True)
    (target_path / "labels" / "train").mkdir(parents=True, exist_ok=True)
    (target_path / "images" / "val").mkdir(parents=True, exist_ok=True)
    (target_path / "labels" / "val").mkdir(parents=True, exist_ok=True)
    (target_path / "images" / "test").mkdir(parents=True, exist_ok=True)
    (target_path / "labels" / "test").mkdir(parents=True, exist_ok=True)
    
    image_files = list((source_path / "images").glob("*.jpg")) # Asumsi ekstensi .jpg
    
    # Shuffle file untuk pembagian yang adil
    np.random.shuffle(image_files)
    
    num_files = len(image_files)
    num_train = int(num_files * train_ratio)
    num_val = int(num_files * val_ratio)
    
    # Bagi file
    train_files = image_files[:num_train]
    val_files = image_files[num_train:num_train + num_val]
    test_files = image_files[num_train + num_val:]
    
    splits = {'train': train_files, 'val': val_files, 'test': test_files}
    
    for split_name, files in splits.items():
        print(f"Memproses {split_name}: {len(files)} file...")
        
        for img_path in files:
            label_name = img_path.stem + '.txt'
            label_path_orig = source_path / "labels" / label_name
            
            # Tentukan path output
            img_path_out = target_path / "images" / split_name / img_path.name
            label_path_out = target_path / "labels" / split_name / label_name
            
            img = cv2.imread(str(img_path))
            if img is None:
                print(f"Gagal memuat gambar: {img_path}")
                continue
                
            img_h, img_w, _ = img.shape
            new_annotations = []
            
            if label_path_orig.exists():
                with open(label_path_orig, 'r') as f:
                    lines = f.readlines()
                
                for line in lines:
                    try:
                        # Asumsi format YOLO asli hanya memiliki 1 kelas: '0'
                        parts = line.strip().split()
                        # Kita hanya mengambil koordinat x_c, y_c, w, h
                        _, x_c, y_c, w, h = map(float, parts) 
                    except ValueError:
                        print(f"Skipping malformed line in {label_path_orig}")
                        continue

                    # Konversi dari normalisasi (0-1) ke pixel
                    x_center = int(x_c * img_w)
                    y_center = int(y_c * img_h)
                    width = int(w * img_w)
                    height = int(h * img_h)
                    
                    # Dapatkan koordinat untuk cropping
                    x1 = max(0, int(x_center - width / 2))
                    y1 = max(0, int(y_center - height / 2))
                    x2 = min(img_w, int(x_center + width / 2))
                    y2 = min(img_h, int(y_center + height / 2))
                    
                    # Crop bounding box area
                    cap_patch = img[y1:y2, x1:x2]
                    
                    if cap_patch.size > 0:
                        # Konversi ke HSV
                        cap_patch_hsv = cv2.cvtColor(cap_patch, cv2.COLOR_BGR2HSV)
                        # Tentukan kelas baru (0, 1, atau 2)
                        new_class_id = get_yolo_class(cap_patch_hsv)
                    else:
                        new_class_id = 2 # Default ke Others jika crop gagal
                        
                    # Simpan anotasi baru (kelas baru, koordinat asli)
                    new_annotations.append(f"{new_class_id} {x_c} {y_c} {w} {h}\n")
            
                # Tulis file label baru
                with open(label_path_out, 'w') as f:
                    f.writelines(new_annotations)
            
            # Salin file gambar
            cv2.imwrite(str(img_path_out), img) # Menggunakan imwrite untuk menyalin

    print(f"\nPenyesuaian label selesai. Data baru tersimpan di: {target_path}")

relabel_dataset(data_root, target_root)
# Out:
# --- Memulai Penyesuaian Label Dataset ---
# Memproses train: 9 file...
# Memproses val: 1 file...
# Memproses test: 2 file...
#
# Penyesuaian label selesai. Data baru tersimpan di: data\bottles_relabelled

# %%
data_root = Path('./data/raw_bottles/') 
file_count = len(list((data_root / "images").glob("*.jpg")))

print(f"Jumlah file JPG yang ditemukan: {file_count}")
# Out:
# Jumlah file JPG yang ditemukan: 12

# %%
import yaml
from pathlib import Path

config_data = {
    'path': './data/bottles_relabelled',
    'train': 'images/train',
    'val': 'images/val',
    'names': {
        0: 'light_blue',
        1: 'dark_blue',
        2: 'others'
    }
}

config_path = Path('./data_config.yaml')

with open(config_path, 'w') as f:
    yaml.dump(config_data, f, sort_keys=False)

print(f"File konfigurasi YOLOv8 telah dibuat di: {config_path.resolve()}")
# Out:
# File konfigurasi YOLOv8 telah dibuat di: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data_config.yaml

# %%
#model awal (default)
from ultralytics import YOLO

# Model Nano
print("--- Memulai Training 1: Baseline (Default Hyperparameters) ---")
model_baseline = YOLO('yolov8n.pt') 

# Hyperparameter
img_size = 640
epochs = 50                 
batch_size = 12 # Maksimum batch size agar muat di 12 file

# Training dan Integrasi WandB
print("Memulai proses fine-tuning model YOLOv8n dengan WandB...")

results_baseline = model_baseline.train(
    data='data_config.yaml',    
    epochs=epochs,              
    imgsz=img_size,
    batch=batch_size,
    project='ada-mata-bottle-cap-sorting',
    name='yolov8n_baseline_run',
)

print("\nTraining Baseline Selesai.")
# Out:
# --- Memulai Training 1: Baseline (Default Hyperparameters) ---
# Memulai proses fine-tuning model YOLOv8n dengan WandB...
# Ultralytics 8.3.228  Python-3.9.25 torch-2.8.0+cpu CPU (Intel Core i5-10500H 2.50GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=12, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data_config.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8n_baseline_run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=ada-mata-bottle-cap-sorting, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_baseline_run, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.10.1 ms, read: 3.80.8 MB/s, size: 50.7 KB)
# train: Scanning C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\labels\train... 12 images, 0 backgrounds, 3 corrupt: 100% ━━━━━━━━━━━━ 12/12 218.2it/s 0.1s
# train: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\train\raw-250110_dc_s001_b3_2.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
# train: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\train\raw-250110_dc_s001_b4_1.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
# train: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\train\raw-250110_dc_s001_b4_2.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
# train: New cache created: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\labels\train.cache
# val: Fast image access  (ping: 0.10.0 ms, read: 3.60.3 MB/s, size: 46.9 KB)
# val: Scanning C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\labels\val... 2 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 2/2 121.3it/s 0.0s
# val: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\val\raw-250110_dc_s001_b2_1.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
# val: New cache created: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\labels\val.cache
# Plotting labels to C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_baseline_run\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.00046875), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_baseline_run
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G      1.421      4.045     0.9816         85        640: 100% ━━━━━━━━━━━━ 1/1 5.4s/it 5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.1it/s 0.3s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      1.491      4.089      0.993        117        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.191      3.795      1.011         78        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.1it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.086      3.904     0.9298        100        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G     0.8372      3.766     0.8838        110        640: 100% ━━━━━━━━━━━━ 1/1 5.1s/it 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G     0.8202        3.8     0.8566        113        640: 100% ━━━━━━━━━━━━ 1/1 5.0s/it 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G     0.7919      3.482     0.8447        100        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G     0.8933       3.37      0.871         79        640: 100% ━━━━━━━━━━━━ 1/1 4.8s/it 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G     0.9002      3.208     0.8432        133        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G     0.9572      2.918     0.8524         68        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G     0.8591      2.646     0.8366         95        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G     0.7203       2.43     0.8274        100        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G     0.6686      2.207     0.8433        112        640: 100% ━━━━━━━━━━━━ 1/1 4.8s/it 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.1it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G     0.6526       2.01     0.8163         82        640: 100% ━━━━━━━━━━━━ 1/1 5.0s/it 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G     0.6095      1.838     0.8295        101        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G     0.6129      1.802     0.8082        103        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G     0.7208      1.539     0.8104         92        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G      0.705      1.625     0.8074         81        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.9it/s 0.1s
#                    all          1          6     0.0105        0.2      0.201     0.0704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G     0.5807      1.553      0.811         62        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8it/s 0.1s
#                    all          1          6     0.0105        0.2      0.201     0.0704
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G     0.6376      1.404     0.8549         92        640: 100% ━━━━━━━━━━━━ 1/1 5.2s/it 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.8it/s 0.3s
#                    all          1          6     0.0155        0.3      0.301       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G     0.6419      1.477     0.8076         76        640: 100% ━━━━━━━━━━━━ 1/1 5.1s/it 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          1          6     0.0155        0.3      0.301       0.14
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G     0.6956      1.699     0.8482         72        640: 100% ━━━━━━━━━━━━ 1/1 5.4s/it 5.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          1          6     0.0313          1      0.481      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G     0.6693      1.335     0.8345         88        640: 100% ━━━━━━━━━━━━ 1/1 5.7s/it 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          1          6     0.0313          1      0.481      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G     0.6418      1.253     0.8169         85        640: 100% ━━━━━━━━━━━━ 1/1 5.2s/it 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.1it/s 0.2s
#                    all          1          6     0.0311          1       0.58      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G     0.6457      1.454     0.8241        132        640: 100% ━━━━━━━━━━━━ 1/1 5.7s/it 5.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all          1          6     0.0311          1       0.58      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G     0.5552      1.237     0.8245         86        640: 100% ━━━━━━━━━━━━ 1/1 6.1s/it 6.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          1          6     0.0323          1       0.58      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G     0.6179      1.498     0.8314         69        640: 100% ━━━━━━━━━━━━ 1/1 5.6s/it 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          1          6     0.0323          1       0.58      0.407
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G     0.5494      1.139     0.8107         78        640: 100% ━━━━━━━━━━━━ 1/1 5.3s/it 5.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          1          6     0.0341          1       0.58      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G     0.6396      1.149      0.834        107        640: 100% ━━━━━━━━━━━━ 1/1 4.8s/it 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8it/s 0.1s
#                    all          1          6     0.0341          1       0.58      0.461
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G     0.5481      1.178     0.8262        132        640: 100% ━━━━━━━━━━━━ 1/1 5.0s/it 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          1          6     0.0366          1       0.58      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G     0.5299      1.041     0.8101        125        640: 100% ━━━━━━━━━━━━ 1/1 5.3s/it 5.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all          1          6     0.0366          1       0.58      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G     0.5995      1.043     0.8035        102        640: 100% ━━━━━━━━━━━━ 1/1 5.1s/it 5.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          1          6     0.0395          1      0.597      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G     0.5455       1.05     0.7752        122        640: 100% ━━━━━━━━━━━━ 1/1 5.2s/it 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.9it/s 0.3s
#                    all          1          6     0.0395          1      0.597      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G     0.5874      1.033     0.8101         95        640: 100% ━━━━━━━━━━━━ 1/1 5.6s/it 5.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.2it/s 0.2s
#                    all          1          6     0.0425          1      0.622      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G     0.5928      1.134     0.8241         79        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          1          6     0.0425          1      0.622      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G     0.5598       1.06     0.8251         86        640: 100% ━━━━━━━━━━━━ 1/1 5.0s/it 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          1          6     0.0425          1      0.622      0.493
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G     0.6048      1.059     0.8167         98        640: 100% ━━━━━━━━━━━━ 1/1 4.9s/it 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                    all          1          6     0.0429          1      0.663      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G     0.5914     0.9967     0.8261         80        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          1          6     0.0429          1      0.663      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G     0.6226      1.025     0.8315         79        640: 100% ━━━━━━━━━━━━ 1/1 4.9s/it 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                    all          1          6     0.0429          1      0.663      0.531
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G     0.5219     0.8846     0.7918         84        640: 100% ━━━━━━━━━━━━ 1/1 4.8s/it 4.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          1          6     0.0438          1      0.746      0.627
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G      0.538      1.132     0.8029         56        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.4it/s 0.3s
#                    all          1          6     0.0438          1      0.746      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G     0.5124      0.998     0.8112         54        640: 100% ━━━━━━━━━━━━ 1/1 4.9s/it 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all          1          6     0.0438          1      0.746      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G     0.5295     0.9535     0.8096         55        640: 100% ━━━━━━━━━━━━ 1/1 5.2s/it 5.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 2.8it/s 0.4s
#                    all          1          6      0.045          1      0.995       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G      0.542     0.9585     0.8304         53        640: 100% ━━━━━━━━━━━━ 1/1 4.9s/it 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          1          6      0.045          1      0.995       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G     0.5362      0.914       0.82         57        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.9it/s 0.2s
#                    all          1          6      0.045          1      0.995       0.85
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.5633     0.9169     0.8076         56        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7it/s 0.1s
#                    all          1          6      0.905        0.5      0.995      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.5227     0.9206     0.8239         55        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.3it/s 0.2s
#                    all          1          6      0.905        0.5      0.995      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G     0.5223     0.9769      0.814         54        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.2it/s 0.2s
#                    all          1          6      0.905        0.5      0.995      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G      0.542     0.8937      0.829         57        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.6it/s 0.2s
#                    all          1          6          1      0.467      0.995      0.889
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G     0.5406      0.866     0.8112         59        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          1          6          1      0.467      0.995      0.889
#
# 50 epochs completed in 0.077 hours.
# Optimizer stripped from C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_baseline_run\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_baseline_run\weights\best.pt, 6.2MB
#
# Validating C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_baseline_run\weights\best.pt...
# Ultralytics 8.3.228  Python-3.9.25 torch-2.8.0+cpu CPU (Intel Core i5-10500H 2.50GHz)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3it/s 0.8s
#                    all          1          6          1      0.467      0.995      0.889
#              dark_blue          1          5          1      0.934      0.995      0.882
#                 others          1          1          1          0      0.995      0.895
# Speed: 2.4ms preprocess, 731.2ms inference, 0.0ms loss, 13.1ms postprocess per image
# Results saved to C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_baseline_run
#
# Training Baseline Selesai.

# %%
from ultralytics import YOLO

# Model Nano
print("\n--- Memulai Training 2: Revisi (Regularization Ditingkatkan) ---")
model_regularized = YOLO('yolov8n.pt') 

# Hyperparameter
img_size = 640
epochs = 100                
batch_size = 12 # Maksimum batch size agar muat di 12 file
initial_lr = 0.001
weight_decay_val = 0.005

# Training dan Integrasi WandB
print("Memulai proses fine-tuning model YOLOv8n dengan WandB...")

results_regularized = model_regularized.train(
    data='data_config.yaml',    # Menggunakan file config
    epochs=epochs,              
    imgsz=img_size,
    batch=batch_size,
    lr0=initial_lr,
    weight_decay=weight_decay_val,
    project='ada-mata-bottle-cap-sorting',
    name='yolov8n_regularized_run',
)

print("\nTraining Revisi Selesai.")
# Out:
# --- Memulai Training 2: Revisi (Regularization Ditingkatkan) ---
# Memulai proses fine-tuning model YOLOv8n dengan WandB...
# Ultralytics 8.3.228  Python-3.9.25 torch-2.8.0+cpu CPU (Intel Core i5-10500H 2.50GHz)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=12, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data_config.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8n_regularized_run, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=ada-mata-bottle-cap-sorting, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_regularized_run, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.30.2 ms, read: 131.5105.7 MB/s, size: 50.0 KB)
# train: Scanning C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\labels\train.cache... 12 images, 0 backgrounds, 3 corrupt: 100% ━━━━━━━━━━━━ 12/12 2.7Kit/s 0.0s
# train: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\train\raw-250110_dc_s001_b3_2.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
# train: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\train\raw-250110_dc_s001_b4_1.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
# train: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\train\raw-250110_dc_s001_b4_2.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
# val: Fast image access  (ping: 0.20.0 ms, read: 83.441.0 MB/s, size: 46.9 KB)
# val: Scanning C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\labels\val.cache... 2 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 2/2 656.1it/s 0.0s
# val: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\val\raw-250110_dc_s001_b2_1.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
# Plotting labels to C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_regularized_run\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0046875), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_regularized_run
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.421      4.045     0.9816         85        640: 100% ━━━━━━━━━━━━ 1/1 6.4s/it 6.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      1.491      4.089      0.993        117        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.6it/s 0.3s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G       1.19      3.795      1.011         78        640: 100% ━━━━━━━━━━━━ 1/1 5.0s/it 5.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.8it/s 0.3s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G      1.083      3.901      0.929        100        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G     0.8323      3.759     0.8831        110        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.7it/s 0.3s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G     0.8137       3.79     0.8551        113        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.3it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G     0.8033      3.468     0.8451        100        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G     0.9257      3.336     0.8741         79        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G     0.9352       3.17      0.847        133        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.0it/s 0.3s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100         0G      1.007      2.855     0.8599         68        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.2it/s 0.2s
#                    all          1          6          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100         0G      0.878      2.556     0.8366         95        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          1          6     0.0245        0.9     0.0226     0.0188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100         0G     0.7335      2.327     0.8266        100        640: 100% ━━━━━━━━━━━━ 1/1 4.9s/it 4.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          1          6     0.0301          1     0.0309     0.0266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         0G     0.6728      2.085     0.8417        112        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.4it/s 0.2s
#                    all          1          6     0.0301          1     0.0309     0.0266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100         0G     0.6711      1.884     0.8242         82        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          1          6       0.03          1     0.0307     0.0279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100         0G     0.6182      1.709     0.8261        101        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          1          6       0.03          1     0.0307     0.0279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100         0G      0.618      1.687     0.8082        103        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          1          6     0.0297          1     0.0298     0.0269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100         0G     0.7273      1.477      0.812         92        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.2it/s 0.2s
#                    all          1          6     0.0297          1     0.0298     0.0269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100         0G     0.7213      1.531     0.8094         81        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          1          6     0.0303          1     0.0305     0.0261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100         0G     0.6042      1.509     0.8142         62        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          1          6     0.0303          1     0.0305     0.0261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100         0G      0.658      1.296     0.8541         92        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8it/s 0.1s
#                    all          1          6      0.029          1      0.158     0.0759
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100         0G     0.6487      1.434     0.8089         76        640: 100% ━━━━━━━━━━━━ 1/1 4.0s/it 4.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          1          6      0.029          1      0.158     0.0759
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100         0G     0.7054      1.756     0.8485         72        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          1          6     0.0257        0.9      0.449      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100         0G     0.6523      1.267     0.8296         88        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          1          6     0.0257        0.9      0.449      0.199
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100         0G     0.6311       1.23     0.8175         85        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.5it/s 0.2s
#                    all          1          6     0.0268        0.9      0.463       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100         0G     0.6414      1.407     0.8249        132        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          1          6     0.0268        0.9      0.463       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100         0G     0.5542      1.168     0.8249         86        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          1          6     0.0355          1       0.58      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100         0G     0.5839      1.414      0.822         69        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          1          6     0.0355          1       0.58      0.464
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100         0G     0.5604      1.108      0.815         78        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.6it/s 0.2s
#                    all          1          6     0.0363          1      0.564       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100         0G     0.6343      1.087     0.8365        107        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.4it/s 0.2s
#                    all          1          6     0.0363          1      0.564       0.45
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100         0G     0.5699      1.109     0.8306        132        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6it/s 0.2s
#                    all          1          6     0.0365          1      0.597      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100         0G     0.5182     0.9901      0.811        125        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          1          6     0.0365          1      0.597      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100         0G      0.578     0.9703     0.7995        102        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6it/s 0.2s
#                    all          1          6     0.0359          1      0.663      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100         0G      0.585     0.9501     0.7837        122        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.9it/s 0.1s
#                    all          1          6     0.0359          1      0.663      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100         0G     0.5772     0.9102     0.8113         95        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          1          6     0.0397          1      0.663       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100         0G     0.5956     0.9519     0.8304         79        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          1          6     0.0397          1      0.663       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100         0G     0.5976     0.9201     0.8343         86        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7it/s 0.1s
#                    all          1          6     0.0397          1      0.663       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100         0G      0.652     0.9207      0.832         98        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          1          6     0.0422          1      0.663      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100         0G     0.5986     0.8549     0.8332         80        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          1          6     0.0422          1      0.663      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100         0G     0.6057     0.9065     0.8376         79        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          1          6     0.0422          1      0.663      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100         0G     0.5246     0.8036      0.801         84        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.4it/s 0.1s
#                    all          1          6     0.0433          1      0.622      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100         0G     0.5981     0.8957     0.7983        181        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          1          6     0.0433          1      0.622      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100         0G     0.5288     0.8116     0.8125        118        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          1          6     0.0433          1      0.622      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100         0G     0.5614     0.7598     0.8159        126        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.1it/s 0.1s
#                    all          1          6     0.0427          1      0.605      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100         0G     0.5122     0.8022     0.8221         84        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          1          6     0.0427          1      0.605      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100         0G     0.5549     0.7522     0.8461        108        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.0it/s 0.1s
#                    all          1          6     0.0427          1      0.605      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100         0G     0.5533     0.7387      0.808        122        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.9it/s 0.1s
#                    all          1          6     0.0431          1      0.552      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100         0G     0.5123      0.656      0.825        105        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          1          6     0.0431          1      0.552      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100         0G     0.5836      0.766     0.8421         93        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6it/s 0.2s
#                    all          1          6     0.0431          1      0.552      0.507
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100         0G     0.6047     0.7789     0.8437         76        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.5it/s 0.2s
#                    all          1          6      0.573        0.5      0.216      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100         0G     0.5076     0.6504     0.8362        104        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.4it/s 0.2s
#                    all          1          6      0.573        0.5      0.216      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100         0G     0.5451     0.7681     0.8327         98        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          1          6      0.573        0.5      0.216      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100         0G     0.6094     0.7447     0.8214        122        640: 100% ━━━━━━━━━━━━ 1/1 4.7s/it 4.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6it/s 0.2s
#                    all          1          6      0.575        0.5      0.333      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100         0G     0.5651     0.8422      0.854         77        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.9it/s 0.2s
#                    all          1          6      0.575        0.5      0.333      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100         0G      0.529     0.6733     0.8343         80        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          1          6      0.575        0.5      0.333      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100         0G      0.533     0.6255     0.8225        109        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          1          6      0.579      0.867      0.653      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100         0G     0.4968     0.6555      0.839         80        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          1          6      0.579      0.867      0.653      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100         0G     0.4836     0.6267     0.8253         84        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.0it/s 0.2s
#                    all          1          6      0.579      0.867      0.653      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100         0G     0.5684     0.6914      0.849        102        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          1          6     0.0443          1      0.995      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100         0G     0.4882     0.6746     0.8061         86        640: 100% ━━━━━━━━━━━━ 1/1 4.0s/it 4.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7it/s 0.1s
#                    all          1          6     0.0443          1      0.995      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100         0G     0.5348     0.6396      0.833        116        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.4it/s 0.2s
#                    all          1          6     0.0443          1      0.995      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100         0G     0.5088     0.6489     0.8135         89        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.3it/s 0.2s
#                    all          1          6     0.0443          1      0.995      0.921
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100         0G     0.5245     0.6457     0.8359        127        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.5it/s 0.2s
#                    all          1          6      0.977        0.5      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100         0G       0.46     0.6452     0.8106         65        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.0it/s 0.1s
#                    all          1          6      0.977        0.5      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100         0G     0.4976     0.5971     0.8177        116        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          1          6      0.977        0.5      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100         0G     0.5102      0.682     0.8048        126        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.1it/s 0.2s
#                    all          1          6      0.977        0.5      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100         0G     0.5933     0.6394     0.8236        119        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.8it/s 0.1s
#                    all          1          6          1      0.461      0.995      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100         0G     0.5367     0.6161     0.8175        106        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.0it/s 0.2s
#                    all          1          6          1      0.461      0.995      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100         0G     0.5459     0.6504     0.8027        119        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.1it/s 0.1s
#                    all          1          6          1      0.461      0.995      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100         0G     0.5864     0.6371     0.8072        127        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.6it/s 0.2s
#                    all          1          6          1      0.461      0.995      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100         0G     0.4845     0.6296      0.819         81        640: 100% ━━━━━━━━━━━━ 1/1 4.5s/it 4.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          1          6      0.949        0.5      0.995      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100         0G     0.5317     0.6299     0.8231        125        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          1          6      0.949        0.5      0.995      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100         0G     0.5039     0.6735      0.825        110        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.3it/s 0.1s
#                    all          1          6      0.949        0.5      0.995      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100         0G     0.4826     0.6078     0.8192         95        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.4it/s 0.2s
#                    all          1          6      0.949        0.5      0.995      0.887
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100         0G      0.494     0.6443     0.8086        120        640: 100% ━━━━━━━━━━━━ 1/1 4.6s/it 4.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.7it/s 0.1s
#                    all          1          6      0.915        0.5      0.995      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100         0G     0.4977     0.5706     0.8204        101        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.4it/s 0.2s
#                    all          1          6      0.915        0.5      0.995      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100         0G     0.4632     0.6169     0.8254         76        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.9it/s 0.1s
#                    all          1          6      0.915        0.5      0.995      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100         0G     0.5486     0.5847     0.8388         90        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.8it/s 0.2s
#                    all          1          6      0.915        0.5      0.995      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100         0G     0.4366     0.7316     0.8229         69        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.1it/s 0.1s
#                    all          1          6      0.899        0.5      0.995      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100         0G     0.5504     0.5956      0.807        140        640: 100% ━━━━━━━━━━━━ 1/1 4.2s/it 4.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.9it/s 0.1s
#                    all          1          6      0.899        0.5      0.995      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100         0G     0.5043     0.6013     0.8399         72        640: 100% ━━━━━━━━━━━━ 1/1 4.4s/it 4.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.5it/s 0.2s
#                    all          1          6      0.871        0.5      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100         0G      0.437     0.6502     0.8017         57        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.1it/s 0.2s
#                    all          1          6      0.871        0.5      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100         0G     0.4595     0.6305     0.7989         54        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 5.7it/s 0.2s
#                    all          1          6      0.867        0.5      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100         0G     0.4568     0.5848     0.8058         57        640: 100% ━━━━━━━━━━━━ 1/1 4.1s/it 4.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.3it/s 0.2s
#                    all          1          6      0.867        0.5      0.995      0.922
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100         0G     0.4797     0.6302     0.8149         55        640: 100% ━━━━━━━━━━━━ 1/1 4.3s/it 4.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 6.2it/s 0.2s
#                    all          1          6      0.867        0.5      0.995      0.922
#
# 100 epochs completed in 0.138 hours.
# Optimizer stripped from C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_regularized_run\weights\last.pt, 6.2MB
# Optimizer stripped from C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_regularized_run\weights\best.pt, 6.2MB
#
# Validating C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_regularized_run\weights\best.pt...
# Ultralytics 8.3.228  Python-3.9.25 torch-2.8.0+cpu CPU (Intel Core i5-10500H 2.50GHz)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.6it/s 0.6s
#                    all          1          6      0.977        0.5      0.995      0.922
#              dark_blue          1          5      0.953          1      0.995      0.948
#                 others          1          1          1          0      0.995      0.895
# Speed: 2.0ms preprocess, 573.0ms inference, 0.0ms loss, 12.7ms postprocess per image
# Results saved to C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\ada-mata-bottle-cap-sorting\yolov8n_regularized_run
#
# Training Revisi Selesai.

# %%
# FUNGSI EVALUASI DAN PERBANDINGAN 

model_path_baseline = Path(f'{project_name_dir}/yolov8n_baseline_run/weights/best.pt') 
model_path_revisi = Path(f'{project_name_dir}/yolov8n_regularized_run/weights/best.pt') 
n_tests = 100 
device = 'cuda' if torch.cuda.is_available() else 'cpu' 
# -----------------------------------------------

def evaluate_model_run(model_path: Path, run_name: str, sample_img: np.ndarray, config_path: str) -> dict:
    """Melakukan evaluasi metrik dan mengukur waktu inferensi."""
    print(f"\n=======================================================")
    print(f"EVALUASI MODEL: {run_name}")
    print(f"=======================================================")
    
    try:
        model = YOLO(str(model_path))
        # 'device' sekarang tersedia di scope global
        model.to(device) 
    except FileNotFoundError:
        print(f"ERROR: Model tidak ditemukan di {model_path}. Lewati evaluasi.")
        return {}

    # Pengujian Kecepatan Inferensi
    avg_time_ms = np.nan
    if sample_img is not None:
        model.predict(sample_img, verbose=False, device=device) # Cold start
        timing_data = []
        for _ in range(n_tests):
            start_time = time.time()
            model.predict(sample_img, verbose=False, device=device)
            timing_data.append(time.time() - start_time)
        avg_time_ms = np.mean(timing_data) * 1000

    # Evaluasi Kuantitatif
    metrics = model.val(data=config_path, verbose=False)
    
    # Ekstraksi mAP50 per kelas 
    mAP50_per_class = np.array(metrics.box.all_ap)[:, 0]
    validated_classes = metrics.box.ap_class_index.tolist()

    results_per_class = {'mAP50_LB': 0.0, 'mAP50_DB': 0.0, 'mAP50_Others': 0.0}

    # Isi hasil hanya untuk kelas yang divalidasi
    for i, class_id in enumerate(validated_classes):
        mAP50_value = mAP50_per_class[i]
        if class_id == 0: results_per_class['mAP50_LB'] = mAP50_value
        elif class_id == 1: results_per_class['mAP50_DB'] = mAP50_value
        elif class_id == 2: results_per_class['mAP50_Others'] = mAP50_value

    results = {
        'mAP@0.5': metrics.box.map50,
        'Speed_ms': avg_time_ms,
        **results_per_class,
        'Device': device.upper()
    }
    
    print(f"Selesai. mAP@0.5: {results['mAP@0.5']:.4f}, Speed: {results['Speed_ms']:.3f} ms")
    return results

# RUNNING EVALUASI & PERBANDINGAN FINAL 

sample_img = cv2.imread(str(test_image_path))

comparison_results = {}
comparison_results['Baseline'] = evaluate_model_run(model_path_baseline, "Baseline", sample_img, config_path)
comparison_results['Revisi'] = evaluate_model_run(model_path_revisi, "Revisi", sample_img, config_path)

df = pd.DataFrame.from_dict(comparison_results, orient='index')

# Tampilkan tabel perbandingan
df_final = df[['mAP@0.5', 'mAP50_LB', 'mAP50_DB', 'mAP50_Others', 'Speed_ms', 'Device']]
df_final.columns = ['mAP@0.5', 'Light Blue', 'Dark Blue', 'Others', 'Speed (ms)', 'Device']
print("\n\nTABEL PERBANDINGAN AKHIR:")
print(df_final.to_markdown(floatfmt=".4f"))
# Out:
# =======================================================
# EVALUASI MODEL: Baseline
# =======================================================
# val: Fast image access  (ping: 0.10.0 ms, read: 336.324.1 MB/s, size: 46.9 KB)
# val: Scanning C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\labels\val.cache... 2 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 2/2 1.0Kit/s 0.0s
# val: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\val\raw-250110_dc_s001_b2_1.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 9.9it/s 0.1ss
#                    all          1          6          1      0.467      0.995      0.889
# Speed: 2.3ms preprocess, 78.3ms inference, 0.0ms loss, 5.1ms postprocess per image
# Results saved to C:\Users\haikalef\runs\detect\val20
# Selesai. mAP@0.5: 0.9950, Speed: 73.530 ms
#
# =======================================================
# EVALUASI MODEL: Revisi
# =======================================================
# val: Fast image access  (ping: 0.10.0 ms, read: 247.217.6 MB/s, size: 46.9 KB)
# val: Scanning C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\labels\val.cache... 2 images, 0 backgrounds, 1 corrupt: 100% ━━━━━━━━━━━━ 2/2 989.3it/s 0.0s
# val: C:\Users\haikalef\Documents\Test Adamata\bottle-sorter\data\bottles_relabelled\images\val\raw-250110_dc_s001_b2_1.jpg: ignoring corrupt image/label: could not convert string to float: 'None'
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 7.8it/s 0.1s
#                    all          1          6      0.977        0.5      0.995      0.922
# Speed: 1.4ms preprocess, 97.1ms inference, 0.0ms loss, 12.6ms postprocess per image
# Results saved to C:\Users\haikalef\runs\detect\val21
# Selesai. mAP@0.5: 0.9950, Speed: 78.392 ms
#
#
# TABEL PERBANDINGAN AKHIR:
# |          |   mAP@0.5 |   Light Blue |   Dark Blue |   Others |   Speed (ms) | Device   |
# |:---------|----------:|-------------:|------------:|---------:|-------------:|:---------|
# | Baseline |    0.9950 |       0.0000 |      0.9950 |   0.9950 |      73.5303 | CPU      |
# | Revisi   |    0.9950 |       0.0000 |      0.9950 |   0.9950 |      78.3922 | CPU      |
